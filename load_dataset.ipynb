# %%
import pandas as pd
import subprocess
import os
from pydub import AudioSegment

# %%
def log(message):
    print(f"[LOG] {message}")

# %%
class Segment:
    def __init__(self, name, start, end):
        self.name = name
        self.start = start
        self.end = end

# %%
class Data:
    def __init__(self, uri, speaker, verification, identification, segments=None):
        self.segments = segments if segments is not None else []
        self.uri = uri
        self.speaker = speaker
        self.verification = verification
        self.identification = identification

    def AddSegment(self, segment):
        self.segments.append(segment)
    
    def Print(self):
        print("SPEAKER: ", self.speaker)
        print("URI: ", self.uri)
        print("SEGMENTS: ")
        for segment in self.segments:
            print('\t name: ', segment.name)
            print('\t start: ', segment.start)
            print('\t end: ', segment.end)

# %%
def DecodeFromCSV(csv_file):
    data = pd.read_csv(csv_file)

    data_objects = {}

    for index, row in data.iterrows():
        segment = Segment(row['segment'], row['start'], row['end'])
        uri = row['uri']

        if uri not in data_objects:
            data_objects[uri] = Data(uri, row['speaker'], row['verification'], row['identification'])
        
        data_objects[uri].AddSegment(segment)

    return list(data_objects.values())

# %%
data_objects = DecodeFromCSV('./datasets/voxceleb/data/v1/voxceleb1.csv')

# %%
def download_youtube_video(youtube_id, save_directory='./data_video/temp'):
    output_path = os.path.join(save_directory, f'{youtube_id}.mp4')
    if not os.path.exists(output_path):
        log(f"Скачивание видео {youtube_id}...")
        command = [
            'yt-dlp',
            '-f', 'bestvideo+bestaudio',
            '--merge-output-format', 'mp4',
            f'https://www.youtube.com/watch?v={youtube_id}',
            '--output', output_path
        ]
        process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        for output in process.stdout:
            print(output, end='')
            
        log(f"Видео {youtube_id} скачано!")

# %%
def convert_video_gpu(input_file, output_file):
    log(f"Конвертация видео {input_file} в {output_file} с использованием GPU...")
    command = [
        'ffmpeg', '-threads', '1', '-y', '-hwaccel', 'cuda', '-i', input_file, 
        '-async', '1', '-qscale:v', '5', '-r', '25', 
        '-vf', 'yadif,scale=640:360', '-c:v', 'h264_nvenc', '-c:a', 'aac',
        output_file
    ]
    result = subprocess.run(command, text=True, capture_output=True)

    if result.returncode != 0:
        log(f"Ошибка при конвертации {input_file}: {result.stderr}")
        with open("error_log.txt", "a") as log_file:
            log_file.write(f"Ошибка с {input_file}: {result.stderr}\n")
    else:
        log(f"Видео {input_file} сконвертировано в {output_file}!")

# %%
def convert_video_cpu(input_file, output_file):
    log(f"Конвертация видео {input_file} в {output_file}...")
    command = [
        'ffmpeg', '-threads', '1', '-y', '-i', input_file, 
        '-async', '1', '-qscale:v', '5', '-r', '25', 
        '-vf', 'yadif,scale=trunc(iw/2)*2:-1', '-c:v', 'libx264', '-c:a', 'aac',
        output_file
    ]
    result = subprocess.run(command, text=True, capture_output=True)

    if result.returncode != 0:
        log(f"Ошибка при конвертации {input_file}: {result.stderr}")
        with open("error_log.txt", "a") as log_file:
            log_file.write(f"Ошибка с {input_file}: {result.stderr}\n")
    else:
        log(f"Видео {input_file} сконвертировано в {output_file}!")

# %%
def slice_video(input_file, start_time, end_time, output_file):
    log(f"Нарезка видео {input_file} с {start_time} до {end_time} в {output_file}...")
    
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    
    command = [
        'ffmpeg', '-y', '-i', input_file, '-ss', str(start_time), 
        '-to', str(end_time), '-c:v', 'libx264', '-c:a', 'aac', output_file
    ]
    result = subprocess.run(command, text=True, capture_output=True)
    
    if result.returncode != 0:
        log(f"Ошибка при нарезке {input_file}: {result.stderr}")
        with open("error_log.txt", "a") as log_file:
            log_file.write(f"Ошибка с {input_file}: {result.stderr}\n")
    else:
        log(f"Фрагмент сохранен в {output_file}!")

# %%
MAX_VIDEO_BY_PERSON = 100
MAX_PERSON = 5

# %%
counter_video_map = {}
counter_video = 0
counter_person = 0

# %%
missing_videos_log = './missing_videos.txt'
for data in data_objects:

    if counter_person >= MAX_PERSON + 1:
        break

    if data.speaker not in counter_video_map:
        counter_video_map[data.speaker] = 0
        counter_person += 1
    counter_video = counter_video_map[data.speaker]
    if counter_video >= MAX_VIDEO_BY_PERSON:
        continue

    print('PERSON: ',  data.speaker, 'CURRENT VIDEO: ', counter_video)

    youtube_id = data.uri.split('/')[-1]
    input_file = f'./data_video/temp/{youtube_id}.mp4'
    converted_file = f'./data_video/temp/converted_{youtube_id}.mp4'

    if not os.path.exists(input_file):
        download_youtube_video(youtube_id)

    if os.path.exists(input_file):

        if not os.path.exists(converted_file):
            convert_video_gpu(input_file, converted_file)

        if os.path.exists(converted_file):
            for segment in data.segments:
                if counter_video < MAX_VIDEO_BY_PERSON:
                    log("Segmentation is started")
                    start_time = segment.start
                    end_time = segment.end
                    output_file = f'./data_video/{segment.name}.mp4'
                    slice_video(converted_file, start_time, end_time, output_file)
                    log("Segmentation is ended")
                    counter_video += 1
                else:
                    counter_video_map[data.speaker] = counter_video
                    break
    else:
        log(f"Файл {input_file} не найден, пропуск...")
        with open(missing_videos_log, 'a') as log_file:
            log_file.write(f"{youtube_id}\n")

    counter_video_map[data.speaker] = counter_video
# Out:
# PERSON:  Aaron_Yoo CURRENT VIDEO:  0
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_1geDB-I2TjE.mp4 с 2.8 до 16.1 в ./data_video/Aaron_Yoo/1geDB-I2TjE_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/1geDB-I2TjE_0000001.mp4!
# [LOG] Segmentation is ended
# PERSON:  Aaron_Yoo CURRENT VIDEO:  1
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_38_N-A-QOUo.mp4 с 34.7 до 40.0 в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000001.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_38_N-A-QOUo.mp4 с 90.1 до 94.6 в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000002.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000002.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_38_N-A-QOUo.mp4 с 101.4 до 108.4 в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000003.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000003.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_38_N-A-QOUo.mp4 с 118.0 до 124.2 в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000004.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000004.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_38_N-A-QOUo.mp4 с 129.4 до 134.8 в ./data_video/Aaron_Yoo/38_N-A-QOUo_0000005.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo
# [download] Destination: data_video\temp\UguBGTDl3FM.f140.m4a
#
# [download]   0.1% of    1.05MiB at  516.99KiB/s ETA 00:02
# [download]   0.3% of    1.05MiB at    1.51MiB/s ETA 00:00
# [download]   0.7% of    1.05MiB at    3.53MiB/s ETA 00:00
# [download]   1.4% of    1.05MiB at    4.99MiB/s ETA 00:00
# [download]   2.9% of    1.05MiB at   10.32MiB/s ETA 00:00
# [download]   5.9% of    1.05MiB at    8.83MiB/s ETA 00:00
# [download]  11.8% of    1.05MiB at    8.53MiB/s ETA 00:00
# [download]  23.7% of    1.05MiB at    8.72MiB/s ETA 00:00
# [download]  47.5% of    1.05MiB at    8.58MiB/s ETA 00:00
# [download]  95.1% of    1.05MiB at    8.51MiB/s ETA 00:00
# [download] 100.0% of    1.05MiB at    8.51MiB/s ETA 00:00
# [download] 100% of    1.05MiB in 00:01:08 at 15.82KiB/s
# [Merger] Merging formats into "data_video\temp\UguBGTDl3FM.mp4"
# Deleting original file data_video\temp\UguBGTDl3FM.f140.m4a (pass -k to keep)
# Deleting original file data_video\temp\UguBGTDl3FM.f135.mp4 (pass -k to keep)
# [LOG] Видео UguBGTDl3FM скачано!
# [LOG] Конвертация видео ./data_video/temp/UguBGTDl3FM.mp4 в ./data_video/temp/converted_UguBGTDl3FM.mp4 с использованием GPU...
# [LOG] Видео ./data_video/temp/UguBGTDl3FM.mp4 сконвертировано в ./data_video/temp/converted_UguBGTDl3FM.mp4!
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_UguBGTDl3FM.mp4 с 17.0 до 22.3 в ./data_video/Aaron_Yoo/UguBGTDl3FM_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/UguBGTDl3FM_0000001.mp4!
# [LOG] Segmentation is ended
# PERSON:  Aaron_Yoo CURRENT VIDEO:  27
# [LOG] Скачивание видео WD-MtwoWSxs...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WD-MtwoWSxs
# [youtube] WD-MtwoWSxs: Downloading webpage
# [youtube] WD-MtwoWSxs: Downloading tv client config
# [youtube] WD-MtwoWSxs: Downloading player 69f581a5
# [youtube] WD-MtwoWSxs: Downloading tv player API JSON
# [youtube] WD-MtwoWSxs: Downloading ios player API JSON
# [youtube] WD-MtwoWSxs: Downloading m3u8 information
# [info] WD-MtwoWSxs: Downloading 1 format(s): 135+140
# [download] Destination: data_video\temp\WD-MtwoWSxs.f135.mp4
#
# [download]   0.0% of   35.39MiB at  111.01KiB/s ETA 05:26
# [download]   0.0% of   35.39MiB at  333.03KiB/s ETA 01:48
# [download]   0.0% of   35.39MiB at  699.35KiB/s ETA 00:51
# [download]   0.0% of   35.39MiB at    1.46MiB/s ETA 00:24
# [download]   0.1% of   35.39MiB at  306.52KiB/s ETA 01:58
# [download]   0.2% of   35.39MiB at  352.58KiB/s ETA 01:42
# [download]   0.4% of   35.39MiB at  480.37KiB/s ETA 01:15
# [download]   0.7% of   35.39MiB at  719.45KiB/s ETA 00:50
# [download]   1.4% of   35.39MiB at  995.70KiB/s ETA 00:35
# [download]   2.8% of   35.39MiB at    1.56MiB/s ETA 00:22
# [download]  93.0% of   35.39MiB at    4.32MiB/s ETA 00:00
# [download] 100.0% of   35.39MiB at    5.23MiB/s ETA 00:00
# [download] 100% of   35.39MiB in 00:00:10 at 3.33MiB/s
# [download] Destination: data_video\temp\WD-MtwoWSxs.f140.m4a
#
# [download]   0.0% of    7.07MiB at  Unknown B/s ETA Unknown
# [download]   0.0% of    7.07MiB at    1.50MiB/s ETA 00:04
# [download]   0.1% of    7.07MiB at    3.49MiB/s ETA 00:02
# [download]   0.2% of    7.07MiB at    7.48MiB/s ETA 00:00
# [download]   0.4% of    7.07MiB at   15.46MiB/s ETA 00:00
# [download]   0.9% of    7.07MiB at   12.33MiB/s ETA 00:00
# [download]   1.8% of    7.07MiB at   11.29MiB/s ETA 00:00
# [download]   3.5% of    7.07MiB at   11.16MiB/s ETA 00:00
# [download]   7.1% of    7.07MiB at   11.21MiB/s ETA 00:00
# [download]  14.1% of    7.07MiB at   11.15MiB/s ETA 00:00
# [download]  28.3% of    7.07MiB at    5.24MiB/s ETA 00:00
# [download]  56.6% of    7.07MiB at    4.74MiB/s ETA 00:00
# [download] 100.0% of    7.07MiB at    6.14MiB/s ETA 00:00
# [download] 100% of    7.07MiB in 00:00:01 at 3.77MiB/s
# [Merger] Merging formats into "data_video\temp\WD-MtwoWSxs.mp4"
# Deleting original file data_video\temp\WD-MtwoWSxs.f135.mp4 (pass -k to keep)
# Deleting original file data_video\temp\WD-MtwoWSxs.f140.m4a (pass -k to keep)
# [LOG] Видео WD-MtwoWSxs скачано!
# [LOG] Конвертация видео ./data_video/temp/WD-MtwoWSxs.mp4 в ./data_video/temp/converted_WD-MtwoWSxs.mp4 с использованием GPU...
# [LOG] Видео ./data_video/temp/WD-MtwoWSxs.mp4 сконвертировано в ./data_video/temp/converted_WD-MtwoWSxs.mp4!
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 272.0 до 277.5 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000001.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 283.2 до 289.7 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000002.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000002.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 293.6 до 299.1 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000003.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000003.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 300.2 до 308.2 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000004.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000004.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 314.0 до 332.6 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000005.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000005.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 349.1 до 364.2 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000006.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000006.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_WD-MtwoWSxs.mp4 с 368.4 до 380.8 в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000007.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/WD-MtwoWSxs_0000007.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted
# [download]   0.8% of    1.77MiB at    7.32MiB/s ETA 00:00
# [download]   1.7% of    1.77MiB at   10.10MiB/s ETA 00:00
# [download]   3.5% of    1.77MiB at   10.25MiB/s ETA 00:00
# [download]   7.0% of    1.77MiB at    9.38MiB/s ETA 00:00
# [download]  14.0% of    1.77MiB at    8.77MiB/s ETA 00:00
# [download]  28.2% of    1.77MiB at    8.65MiB/s ETA 00:00
# [download]  56.4% of    1.77MiB at    8.66MiB/s ETA 00:00
# [download] 100.0% of    1.77MiB at    8.83MiB/s ETA 00:00
# [download] 100% of    1.77MiB in 00:00:00 at 3.22MiB/s
# [Merger] Merging formats into "data_video\temp\Yks5By_Hv_Y.mp4"
# Deleting original file data_video\temp\Yks5By_Hv_Y.f140.m4a (pass -k to keep)
# Deleting original file data_video\temp\Yks5By_Hv_Y.f135.mp4 (pass -k to keep)
# [LOG] Видео Yks5By_Hv_Y скачано!
# [LOG] Конвертация видео ./data_video/temp/Yks5By_Hv_Y.mp4 в ./data_video/temp/converted_Yks5By_Hv_Y.mp4 с использованием GPU...
# [LOG] Видео ./data_video/temp/Yks5By_Hv_Y.mp4 сконвертировано в ./data_video/temp/converted_Yks5By_Hv_Y.mp4!
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_Yks5By_Hv_Y.mp4 с 91.3 до 95.6 в ./data_video/Aaron_Yoo/Yks5By_Hv_Y_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/Yks5By_Hv_Y_0000001.mp4!
# [LOG] Segmentation is ended
# PERSON:  Aaron_Yoo CURRENT VIDEO:  42
# [LOG] Скачивание видео ZZR6EqjbzwI...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZZR6EqjbzwI
# [youtube] ZZR6EqjbzwI: Downloading webpage
# [youtube] ZZR6EqjbzwI: Downloading tv client config
# [youtube] ZZR6EqjbzwI: Downloading player 69f581a5
# [youtube] ZZR6EqjbzwI: Downloading tv player API JSON
# [youtube] ZZR6EqjbzwI: Downloading ios player API JSON
# ERROR: [youtube] ZZR6EqjbzwI: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# [LOG] Видео ZZR6EqjbzwI скачано!
# [LOG] Файл ./data_video/temp/ZZR6EqjbzwI.mp4 не найден, пропуск...
# PERSON:  Aaron_Yoo CURRENT VIDEO:  42
# [LOG] Скачивание видео mzZj5a0FgZY...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mzZj5a0FgZY
# [youtube] mzZj5a0FgZY: Downloading webpage
# [youtube] mzZj5a0FgZY: Downloading tv client config
# [youtube] mzZj5a0FgZY: Downloading player 69f581a5
# [youtube] mzZj5a0FgZY: Downloading tv player API JSON
# [youtube] mzZj5a0FgZY: Downloading ios player API JSON
# [youtube] mzZj5a0FgZY: Downloading m3u8 information
# [info] mzZj5a0FgZY: Downloading 1 format(s): 135+140
# [download] Destination: data_video\temp\mzZj5a0FgZY.f135.mp4
#
# [download]   0.0% of   24.20MiB at  125.10KiB/s ETA 03:18
# [download]   0.0% of   24.20MiB at  334.77KiB/s ETA 01:14
# [download]   0.0% of   24.20MiB at  781.12KiB/s ETA 00:31
# [download]   0.1% of   24.20MiB at    1.63MiB/s ETA 00:14
# [download]  89.3% of   10.77MiB at  Unknown B/s ETA Unknown
# [download]  89.3% of   10.77MiB at    2.93MiB/s ETA 00:00
# [download]  89.3% of   10.77MiB at    6.83MiB/s ETA 00:00
# [download]  89.4% of   10.77MiB at   14.63MiB/s ETA 00:00
# [download]  89.6% of   10.77MiB at   15.16MiB/s ETA 00:00
# [download]  89.8% of   10.77MiB at   10.26MiB/s ETA 00:00
# [download]  90.4% of   10.77MiB at    9.44MiB/s ETA 00:00
# [download]  91.6% of   10.77MiB at    9.11MiB/s ETA 00:00
# [download]  93.9% of   10.77MiB at    1.47MiB/s ETA 00:00
# [download]  98.6% of   10.77MiB at    2.52MiB/s ETA 00:00
# [download] 100.0% of   10.77MiB at    2.80MiB/s ETA 00:00
# [download] 100% of   10.77MiB in 00:00:04 at 2.64MiB/s
# [download] Destination: data_video\temp\oJYptXzCASM.f251.webm
#
# [download]   0.1% of    1.84MiB at  Unknown B/s ETA Unknown
# [download]   0.2% of    1.84MiB at    1.67MiB/s ETA 00:01
# [download]   0.4% of    1.84MiB at    3.91MiB/s ETA 00:00
# [download]   0.8% of    1.84MiB at    8.37MiB/s ETA 00:00
# [download]   1.6% of    1.84MiB at   10.98MiB/s ETA 00:00
# [download]   3.3% of    1.84MiB at    9.05MiB/s ETA 00:00
# [download]   6.7% of    1.84MiB at    9.02MiB/s ETA 00:00
# [download]  13.5% of    1.84MiB at    8.94MiB/s ETA 00:00
# [download]  27.1% of    1.84MiB at    8.69MiB/s ETA 00:00
# [download]  54.3% of    1.84MiB at    8.72MiB/s ETA 00:00
# [download] 100.0% of    1.84MiB at    8.93MiB/s ETA 00:00
# [download] 100% of    1.84MiB in 00:00:00 at 2.45MiB/s
# [Merger] Merging formats into "data_video\temp\oJYptXzCASM.mp4"
# Deleting original file data_video\temp\oJYptXzCASM.f251.webm (pass -k to keep)
# Deleting original file data_video\temp\oJYptXzCASM.f135.mp4 (pass -k to keep)
# [LOG] Видео oJYptXzCASM скачано!
# [LOG] Конвертация видео ./data_video/temp/oJYptXzCASM.mp4 в ./data_video/temp/converted_oJYptXzCASM.mp4 с использованием GPU...
# [LOG] Видео ./data_video/temp/oJYptXzCASM.mp4 сконвертировано в ./data_video/temp/converted_oJYptXzCASM.mp4!
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_oJYptXzCASM.mp4 с 87.9 до 96.2 в ./data_video/Aaron_Yoo/oJYptXzCASM_0000001.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Aaron_Yoo/oJYptXzCASM_0000001.mp4!
# [LOG] Segmentation is ended
# PERSON:  Aaron_Yoo CURRENT VIDEO:  44
# [LOG] Скачивание видео x-1gq_B3snI...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=x-1gq_B3snI
# [youtube] x-1gq_B3snI: Downloading webpage
# [youtube] x-1gq_B3snI: Downloading tv client config
# [youtube] x-1gq_B3snI: Downloading player 69f581a5
# [youtube] x-1gq_B3snI: Downloading tv player API JSON
# [youtube] x-1gq_B3snI: Downloading ios player API JSON
# [youtube] x-1gq_B3snI: Downloading m3u8 information
# [info] x-1gq_B3snI: Downloading 1 format(s): 243+251
# [download] Destination: data_video\temp\x-1gq_B3snI.f243.webm
mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_0otHlFztX8I.mp4 с 161.1 до 176.0 в ./data_video/Abbie_Cornish/0otHlFztX8I_0000013.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Abbie_Cornish/0otHlFztX8I_0000013.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_0otHlFztX8I.mp4 с 184.1 до 192.9 в ./data_video/Abbie_Cornish/0otHlFztX8I_0000014.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Abbie_Cornish/0otHlFztX8I_0000014.mp4!
# [LOG] Segmentation is ended
# [LOG] Segmentation is started
# [LOG] Нарезка видео ./data_video/temp/converted_0otHlFztX8I.mp4 с 193.5 до 204.0 в ./data_video/Abbie_Cornish/0otHlFztX8I_0000015.mp4...
# [LOG] Фрагмент сохранен в ./data_video/Abbie_Cornish/0otHlFztX8I_0000015.mp4!
# [LOG] Segmentation is ended

# %%
def extract_and_split_audio(source_dir, train_dir, test_dir):
    for target_dir in [train_dir, test_dir]:
        if not os.path.exists(target_dir):
            os.makedirs(target_dir)

    for person_name in os.listdir(source_dir):
        person_path = os.path.join(source_dir, person_name)
        
        if os.path.isdir(person_path):
            files = [f for f in os.listdir(person_path) if f.endswith('.mp4')]
            train_index = int(len(files) * 0.8)

            train_files = files[:train_index]
            test_files = files[train_index:]

            process_files(person_name, person_path, train_files, train_dir)
            process_files(person_name, person_path, test_files, test_dir)

def process_files(person_name, person_path, files, target_base_dir):
    target_person_path = os.path.join(target_base_dir, person_name)
    if not os.path.exists(target_person_path):
        os.makedirs(target_person_path)

    for file_name in files:
        video_path = os.path.join(person_path, file_name)
        audio_file_name = os.path.splitext(file_name)[0] + '.wav'
        audio_path = os.path.join(target_person_path, audio_file_name)


        video = AudioSegment.from_file(video_path, format='mp4')
        video.export(audio_path, format='wav')

source_directory = 'data_video'
train_directory = 'data_audio_train'
test_directory = 'data_audio_test'

extract_and_split_audio(source_directory, train_directory, test_directory)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 42
#      39 train_directory = 'data_audio_train'
#      40 test_directory = 'data_audio_test'
# ---> 42 extract_and_split_audio(source_directory, train_directory, test_directory)
#
# Cell In[32], line 20, in extract_and_split_audio(source_dir, train_dir, test_dir)
#      17 train_files = files[:train_index]
#      18 test_files = files[train_index:]
# ---> 20 process_files(person_name, person_path, train_files, train_dir)
#      21 process_files(person_name, person_path, test_files, test_dir)
#
# Cell In[32], line 34, in process_files(person_name, person_path, files, target_base_dir)
#      31 audio_path = os.path.join(target_person_path, audio_file_name)
#      33 # Извлекаем аудио
# ---> 34 video = AudioSegment.from_file(video_path, format='mp4')
#      35 video.export(audio_path, format='wav')
#
# File e:\Study\CourseWork\env\Lib\site-packages\pydub\audio_segment.py:734, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     730 audio_streams = [x for x in info['streams']
#     731                  if x['codec_type'] == 'audio']
#     732 # This is a workaround for some ffprobe versions that always say
#     733 # that mp3/mp4/aac/webm/ogg files contain fltp samples
# --> 734 audio_codec = audio_streams[0].get('codec_name')
#     735 if (audio_streams[0].get('sample_fmt') == 'fltp' and
#     736         audio_codec in ['mp3', 'mp4', 'aac', 'webm', 'ogg']):
#     737     bits_per_sample = 16
#
# IndexError: list index out of range
